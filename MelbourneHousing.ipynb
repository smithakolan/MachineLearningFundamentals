# %% [markdown]
# <a href="https://colab.research.google.com/github/smithakolan/MachineLearningFundamentals/blob/master/MelbourneHousing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# In this exercise you'll try to build a neural network that predicts the price of a house according to a simple formula.
#
# So, imagine if house pricing was as easy as a house costs 50k + 50k per bedroom, so that a 1 bedroom house costs 100k, a 2 bedroom house costs 150k etc.
#
# How would you create a neural network that learns this relationship so that it would predict a 7 bedroom house as costing close to 400k etc.
#
# Hint: Your network might work better if you scale the house price down. You don't have to give the answer 400...it might be better to create something that predicts the number 4, and then your answer is in the 'hundreds of thousands' etc.

# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras

# %%
#house_model
def house_model(y_new):
    xs = [0,1,2,3,4,5,6]
    ys = [0.5,1,1.5,2,2.5,3,3.5]
    model = keras.Sequential([keras.layers.Dense(units=1, input_shape=[1])])
    model.compile(optimizer="sgd", loss='mean_squared_error')
    model.fit(xs, ys, epochs=500)
    return round(model.predict(y_new)[0][0])

# %%
prediction = house_model([7.0])
print(prediction, "hundred thousand dollars")
# Out:
# Epoch 1/500
# 1/1 [==============================] - 0s 4ms/step - loss: 55.0992
# Epoch 2/500
# 1/1 [==============================] - 0s 2ms/step - loss: 29.0286
# Epoch 3/500
# 1/1 [==============================] - 0s 1ms/step - loss: 15.2936
# Epoch 4/500
# 1/1 [==============================] - 0s 2ms/step - loss: 8.0574
# Epoch 5/500
# 1/1 [==============================] - 0s 1ms/step - loss: 4.2452
# Epoch 6/500
# 1/1 [==============================] - 0s 2ms/step - loss: 2.2367
# Epoch 7/500
# 1/1 [==============================] - 0s 2ms/step - loss: 1.1786
# Epoch 8/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.6211
# Epoch 9/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.3274
# Epoch 10/500
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1727
# Epoch 11/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0912
# Epoch 12/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0482
# ...
